# %%
import undetected_chromedriver as uc
import pickle
import pandas as pd

from selenium import webdriver
from selenium.webdriver.support.wait import WebDriverWait
from selenium.webdriver.support import expected_conditions as EC

from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
import time

# %%
"""if __name__ == '__main__':
    options = Options()
    options.add_experimental_option('detach', True)

    path ="C:\Program Files (x86)\chromedriver.exe"
    driver = uc.Chrome() 

    driver.get("https://fd11-courses.leclercdrive.fr/magasin-018201-montauban---sapiac.aspx")
    driver.maximize_window()
    time.sleep(20)

    cookies = driver.get_cookies()
    pickle.dump(cookies, open("cookies.pkl", "wb"))

    time.sleep(2)"""
# Out:
# 'if __name__ == \'__main__\':\n    options = Options()\n    options.add_experimental_option(\'detach\', True)\n\n    path ="C:\\Program Files (x86)\\chromedriver.exe"\n    driver = uc.Chrome() \n\n    driver.get("https://fd11-courses.leclercdrive.fr/magasin-018201-montauban---sapiac.aspx")\n    driver.maximize_window()\n    time.sleep(20)\n\n    cookies = driver.get_cookies()\n    pickle.dump(cookies, open("cookies.pkl", "wb"))\n\n    time.sleep(2)'

# %%
if __name__ == '__main__':
    options = Options()
    options.add_experimental_option('detach', True)

    driver = uc.Chrome() 

    driver.get('https://www.leclercdrive.fr/')
    driver.maximize_window()
    time.sleep(2)
    try:
        
        button = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.ID, 'onetrust-pc-btn-handler'))
        )
        button.click()
        time.sleep(2)

        refuse = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CLASS_NAME, 'ot-pc-refuse-all-handler'))
        )
        refuse.click()
        time.sleep(4)

        search_location = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.ID, 'txtWPAD344_RechercheDrive'))
        )
        search_location.send_keys('82000')
        time.sleep(2)
        search_location.send_keys(Keys.RETURN)
        time.sleep(3)

        drive = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CLASS_NAME, 'ctrlMapLAD__cartouches--titres'))
        )
        drive.click()
        time.sleep(2)

        choisir = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CLASS_NAME, 'popinDriveMagasin__BtnChoix'))
        )
        choisir.click()

        time.sleep(2)

        url_loc = driver.current_url



        cookies = pickle.load(open('cookies.pkl', 'rb'))

        for cookie in cookies: 

            try :
                driver.add_cookie(cookie)
            except Exception as e:
                print(e)


        
        driver.get(url_loc)
        time.sleep(2)

        btn_rayon = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.XPATH, '//*[@id="ctl00_ctl00_mainMutiUnivers_MasterHeader_ctl00_pnlWCAD301_Nav"]/ul/li[1]/a'))
        )
        btn_rayon.click()
        time.sleep(2)


#scrap nom rayons et les liens
        rayons_p = driver.find_elements(by = By.CLASS_NAME, value= 'rayon-droite')
        time.sleep(2)
      
        list_rayons = []
        
        for rayon in rayons_p:
            rayon_p = rayon.find_element(by = By.CLASS_NAME, value= 'rayon-droite-titre')

            rayons_s = rayon.find_elements(by = By.TAG_NAME, value ='a')

            for rayon_s in rayons_s:

                dict_rayons={
                    'rayon principal' : rayon_p.text,
                    'rayon secondaire': rayon_s.text,
                    'lien rayon secondaire' : rayon_s.get_attribute('href')
                }
                list_rayons.append(dict_rayons)
             
        df_rayons = pd.DataFrame(list_rayons)
        #df_rayons.to_csv("list_all_rayon.csv")
        time.sleep(2)
        print(df_rayons['lien rayon secondaire'])

#scrap produits
        list_produits=[]
        for i, lien_rayon in enumerate(df_rayons['lien rayon secondaire']):
            if (i<75) : 
                print(i)
                print(lien_rayon)
                driver.get(lien_rayon) 
                time.sleep(2)
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(6)
                produits = driver.find_elements(by = By.CLASS_NAME, value = 'divWCRS310_Content')
                

                for produit in produits:
                    nom_produit = produit.find_element(by = By.CLASS_NAME, value ='pWCRS310_Desc')
                    #print(nom_produit)

                    prix_ent_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUnitairePartieEntiere')
                    #print(prix_ent_produit)
                    prix_dec_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUnitairePartieDecimale')
                    #print(prix_dec_produit)

                    prix_produit = prix_ent_produit.text + prix_dec_produit.text
                    #print(prix_produit)

                    
                    prix_rat_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUniteMesure')
                    #print(prix_rat_produit)
                    

                    dict_produits={
                        'rayon principal' : df_rayons.iloc[i]['rayon principal'],
                        'rayon secondaire': df_rayons.iloc[i]['rayon secondaire'],
                        'lien rayon secondaire' : df_rayons.iloc[i]['lien rayon secondaire'],
                        'nom_produit' : nom_produit.text,
                        'prix_produit' : prix_produit,
                        'prix_rat_produit' : prix_rat_produit.text
                    }
                    #print("--------------------------------")
                    #print(dict_produits)
                    list_produits.append(dict_produits)
            else : 
                pass
        df_produits = pd.DataFrame(list_produits)
        df_produits.to_csv('list_all_produits_1.csv')
    except:
        driver.quit()
# Out:
# 0      https://fd11-courses.leclercdrive.fr/magasin-0...
# 1      https://fd11-courses.leclercdrive.fr/magasin-0...
# 2      https://fd11-courses.leclercdrive.fr/magasin-0...
# 3      https://fd11-courses.leclercdrive.fr/magasin-0...
# 4      https://fd11-courses.leclercdrive.fr/magasin-0...
#                              ...
# 106    https://fd11-courses.leclercdrive.fr/magasin-0...
# 107    https://fd11-courses.leclercdrive.fr/magasin-0...
# 108    https://fd11-courses.leclercdrive.fr/magasin-0...
# 109    https://fd11-courses.leclercdrive.fr/magasin-0...
# 110    https://fd11-courses.leclercdrive.fr/magasin-0...
# Name: lien rayon secondaire, Length: 111, dtype: object
# 0
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-313315-Chocolats-enfants.aspx
# 1
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-313320-Chocolats-adultes.aspx
# 2
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284557-Le-marche-Bio.aspx
# 3
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284558-Frais-et-Surgeles-Bio.aspx
# 4
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284559-Epicerie-salee-Bio.aspx
# 5
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284560-Epicerie-sucree-Bio.aspx
# 6
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284561-Boissons-Bio.aspx
# 7
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284562-Bebe-Bio.aspx
# 8
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284563-Hygiene-et-beaute-Bio.aspx
# 9
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-304388-Mon-boucher.aspx
# 10
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-304390-Mon-primeur.aspx
# 11
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-304391-Mon-boulanger-patissier.aspx
# 12
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-304392-Mon-fromager.aspx
# 13
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-304393-Mon-charcutier.aspx
# 14
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-304394-Mon-Traiteur.aspx
# 15
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284325-Boucherie.aspx
# 16
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284326-Volailles-et-Gibiers.aspx
# 17
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284327-Poissonnerie.aspx
# 18
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-285187-Traiteur-de-la-mer.aspx
# 19
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284351-Legumes.aspx
# 20
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284349-Fruits.aspx
# 21
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284350-Jus-de-fruits-et-legumes-frais.aspx
# 22
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284358-Pains-et-Patisseries.aspx
# 23
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284361-Pains-de-mie-et-Pains-grilles.aspx
# 24
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284362-Patisseries-moelleuses.aspx
# 25
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284370-Laits-et-Oeufs.aspx
# 26
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284371-Beurres-et-Cremes.aspx
# 27
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284372-Fromages.aspx
# 28
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284373-Charcuteries.aspx
# 29
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284374-Traiteur.aspx
# 30
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284375-Yaourts-et-Produits-Laitiers.aspx
# 31
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284376-Desserts.aspx
# 32
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-298779-Vegetarien-et-vegetal.aspx
# 33
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-286690-Prepare-sur-place-.aspx
# 34
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284247-Aperitifs-Entrees-et-Snacks.aspx
# 35
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284248-Plats-cuisines-Pizzas-Tartes.aspx
# 36
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284249-Viandes-et-Poissons.aspx
# 37
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284250-Legumes-et-Frites.aspx
# 38
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284251-Glaces-et-Desserts-glaces.aspx
# 39
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284421-Pates-Riz-Purees-Feculents.aspx
# 40
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284426-Soupes-et-Croutons.aspx
# 41
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284423-Plats-cuisines.aspx
# 42
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284422-Conserves-de-legumes.aspx
# 43
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-303866-Conserves-de-viande-et-poisson.aspx
# 44
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284424-Aperitifs.aspx
# 45
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284425-Assaisonnements-et-Condiments.aspx
# 46
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-288378-Bouillons-fonds-et-sauces.aspx
# 47
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-288991-Saveurs-du-monde.aspx
# 48
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/offres-313671-Jackpot-de-Printemps.aspx?provenanceNavigation=1001&idProvenanceNavigation=11037
# 49
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284748-Cafes.aspx
# 50
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-293232-Thes-et-Poudres-chocolatees.aspx
# 51
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284467-Petits-dejeuners.aspx
# 52
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284482-Biscuits.aspx
# 53
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284483-Patisseries-moelleuses.aspx
# 54
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284484-Chocolats-et-Tablettes.aspx
# 55
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-304248-Bonbons-et-Chewing-gum.aspx
# 56
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284485-Desserts-Sucres-et-Farines.aspx
# 57
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-288906-Nutrition-et-Bien-etre.aspx
# 58
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/offres-313311-Chocolats-de-Paques.aspx?provenanceNavigation=1001&idProvenanceNavigation=10790
# 59
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284529-Sodas-et-Boissons-aux-fruits.aspx
# 60
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284534-Eaux.aspx
# 61
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-313724-Laits-et-Boissons-vegetales.aspx
# 62
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284520-Jus-de-fruits-et-legumes.aspx
# 63
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-294998-Bieres-et-Cidres.aspx
# 64
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284519-Alcools-et-Aperitifs.aspx
# 65
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-289555-Vins.aspx
# 66
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284518-Champagnes-et-Mousseux.aspx
# 67
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284748-Cafes.aspx?provenanceNavigation=1001&idProvenanceNavigation=10652
# 68
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/offres-313604-Cave-de-Printemps.aspx?provenanceNavigation=1001&idProvenanceNavigation=10984
# 69
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-291327-Le-BIO.aspx
# 70
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284552-Laits-et-Eaux.aspx
# 71
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-312224-Cereales-et-Petits-Dejeuners.aspx
# 72
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284553-Repas-de-bebe.aspx
# 73
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284554-Gouters-Desserts-et-Boissons.aspx
# 74
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284555-Couches-lingettes-et-cotons.aspx

# %%
if __name__ == '__main__':
    options = Options()
    options.add_experimental_option('detach', True)

    driver = uc.Chrome() 

    driver.get('https://www.leclercdrive.fr/')
    driver.maximize_window()
    time.sleep(2)
    try:
        
        button = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.ID, 'onetrust-pc-btn-handler'))
        )
        button.click()
        time.sleep(2)

        refuse = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CLASS_NAME, 'ot-pc-refuse-all-handler'))
        )
        refuse.click()
        time.sleep(4)

        search_location = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.ID, 'txtWPAD344_RechercheDrive'))
        )
        search_location.send_keys('82000')
        time.sleep(2)
        search_location.send_keys(Keys.RETURN)
        time.sleep(3)

        drive = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CLASS_NAME, 'ctrlMapLAD__cartouches--titres'))
        )
        drive.click()
        time.sleep(2)

        choisir = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CLASS_NAME, 'popinDriveMagasin__BtnChoix'))
        )
        choisir.click()

        time.sleep(2)

        url_loc = driver.current_url



        cookies = pickle.load(open('cookies.pkl', 'rb'))

        for cookie in cookies: 

            try :
                driver.add_cookie(cookie)
            except Exception as e:
                print(e)


        
        driver.get(url_loc)
        time.sleep(2)

        btn_rayon = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.XPATH, '//*[@id="ctl00_ctl00_mainMutiUnivers_MasterHeader_ctl00_pnlWCAD301_Nav"]/ul/li[1]/a'))
        )
        btn_rayon.click()
        time.sleep(2)


#scrap nom rayons et les liens
        rayons_p = driver.find_elements(by = By.CLASS_NAME, value= 'rayon-droite')
        time.sleep(2)
      
        list_rayons = []
        
        for rayon in rayons_p:
            rayon_p = rayon.find_element(by = By.CLASS_NAME, value= 'rayon-droite-titre')

            rayons_s = rayon.find_elements(by = By.TAG_NAME, value ='a')

            for rayon_s in rayons_s:

                dict_rayons={
                    'rayon principal' : rayon_p.text,
                    'rayon secondaire': rayon_s.text,
                    'lien rayon secondaire' : rayon_s.get_attribute('href')
                }
                list_rayons.append(dict_rayons)
             
        df_rayons = pd.DataFrame(list_rayons)
        #df_rayons.to_csv("list_all_rayon.csv")
        time.sleep(2)
        print(df_rayons['lien rayon secondaire'])

#scrap produits
        list_produits=[]
        for i, lien_rayon in enumerate(df_rayons['lien rayon secondaire']):
            if ((i>75)& (i<96)) : 
                print(i)
                print(lien_rayon)
                driver.get(lien_rayon) 
                time.sleep(2)
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(6)
                produits = driver.find_elements(by = By.CLASS_NAME, value = 'divWCRS310_Content')
                

                for produit in produits:
                    nom_produit = produit.find_element(by = By.CLASS_NAME, value ='pWCRS310_Desc')
                    #print(nom_produit)

                    prix_ent_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUnitairePartieEntiere')
                    #print(prix_ent_produit)
                    prix_dec_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUnitairePartieDecimale')
                    #print(prix_dec_produit)

                    prix_produit = prix_ent_produit.text + prix_dec_produit.text
                    #print(prix_produit)

                    
                    prix_rat_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUniteMesure')
                    #print(prix_rat_produit)
                    

                    dict_produits={
                        'rayon principal' : df_rayons.iloc[i]['rayon principal'],
                        'rayon secondaire': df_rayons.iloc[i]['rayon secondaire'],
                        'lien rayon secondaire' : df_rayons.iloc[i]['lien rayon secondaire'],
                        'nom_produit' : nom_produit.text,
                        'prix_produit' : prix_produit,
                        'prix_rat_produit' : prix_rat_produit.text
                    }
                    #print("--------------------------------")
                    #print(dict_produits)
                    list_produits.append(dict_produits)
            else : 
                pass
        df_produits = pd.DataFrame(list_produits)
        df_produits.to_csv('list_all_produits_2.csv')
    except:
        driver.quit()
# Out:
# 0      https://fd11-courses.leclercdrive.fr/magasin-0...
# 1      https://fd11-courses.leclercdrive.fr/magasin-0...
# 2      https://fd11-courses.leclercdrive.fr/magasin-0...
# 3      https://fd11-courses.leclercdrive.fr/magasin-0...
# 4      https://fd11-courses.leclercdrive.fr/magasin-0...
#                              ...
# 106    https://fd11-courses.leclercdrive.fr/magasin-0...
# 107    https://fd11-courses.leclercdrive.fr/magasin-0...
# 108    https://fd11-courses.leclercdrive.fr/magasin-0...
# 109    https://fd11-courses.leclercdrive.fr/magasin-0...
# 110    https://fd11-courses.leclercdrive.fr/magasin-0...
# Name: lien rayon secondaire, Length: 111, dtype: object
# 76
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-290362-Bebe.aspx
# 77
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-290393-Solaires.aspx
# 78
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-291164-Hygiene-et-soins-visage.aspx
# 79
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-290388-Hygiene-et-soins-corps.aspx
# 80
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-290389-Hygiene-bucco-dentaire.aspx
# 81
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-290392-Soin-des-cheveux.aspx
# 82
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-301347-Hygiene-feminine.aspx
# 83
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-290391-Sante.aspx
# 84
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-301263-Complements-alimentaires.aspx
# 85
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284593-Hygiene-et-Soins-du-corps.aspx
# 86
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284601-Soins-du-visage-et-Maquillage.aspx
# 87
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284602-Soins-des-cheveux.aspx
# 88
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284611-Hygiene-dentaire.aspx
# 89
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284615-Soins-et-hygiene-des-hommes.aspx
# 90
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284623-Hygiene-feminine-Incontinence.aspx
# 91
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284629-Parapharmacie.aspx
# 92
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284633-Essuie-tout-papiers-et-cotons.aspx
# 93
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284639-Lessives.aspx
# 94
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284645-Entretien-du-linge.aspx
# 95
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284646-Nettoyants-vaisselle.aspx

# %%
if __name__ == '__main__':
    options = Options()
    options.add_experimental_option('detach', True)

    driver = uc.Chrome() 

    driver.get('https://www.leclercdrive.fr/')
    driver.maximize_window()
    time.sleep(2)
    try:
        
        button = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.ID, 'onetrust-pc-btn-handler'))
        )
        button.click()
        time.sleep(2)

        refuse = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CLASS_NAME, 'ot-pc-refuse-all-handler'))
        )
        refuse.click()
        time.sleep(4)

        search_location = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.ID, 'txtWPAD344_RechercheDrive'))
        )
        search_location.send_keys('82000')
        time.sleep(2)
        search_location.send_keys(Keys.RETURN)
        time.sleep(3)

        drive = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CLASS_NAME, 'ctrlMapLAD__cartouches--titres'))
        )
        drive.click()
        time.sleep(2)

        choisir = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.CLASS_NAME, 'popinDriveMagasin__BtnChoix'))
        )
        choisir.click()

        time.sleep(2)

        url_loc = driver.current_url



        cookies = pickle.load(open('cookies.pkl', 'rb'))

        for cookie in cookies: 

            try :
                driver.add_cookie(cookie)
            except Exception as e:
                print(e)


        
        driver.get(url_loc)
        time.sleep(2)

        btn_rayon = WebDriverWait(driver, 10).until(
        EC.presence_of_element_located((By.XPATH, '//*[@id="ctl00_ctl00_mainMutiUnivers_MasterHeader_ctl00_pnlWCAD301_Nav"]/ul/li[1]/a'))
        )
        btn_rayon.click()
        time.sleep(2)


#scrap nom rayons et les liens
        rayons_p = driver.find_elements(by = By.CLASS_NAME, value= 'rayon-droite')
        time.sleep(2)
      
        list_rayons = []
        
        for rayon in rayons_p:
            rayon_p = rayon.find_element(by = By.CLASS_NAME, value= 'rayon-droite-titre')

            rayons_s = rayon.find_elements(by = By.TAG_NAME, value ='a')

            for rayon_s in rayons_s:

                dict_rayons={
                    'rayon principal' : rayon_p.text,
                    'rayon secondaire': rayon_s.text,
                    'lien rayon secondaire' : rayon_s.get_attribute('href')
                }
                list_rayons.append(dict_rayons)
             
        df_rayons = pd.DataFrame(list_rayons)
        #df_rayons.to_csv("list_all_rayon.csv")
        time.sleep(2)
        print(df_rayons['lien rayon secondaire'])

#scrap produits
        list_produits=[]
        for i, lien_rayon in enumerate(df_rayons['lien rayon secondaire']):
            if ((i>96)& (i<98))  : 
                print(i)
                print(lien_rayon)
                driver.get(lien_rayon) 
                time.sleep(2)
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(6)
                produits = driver.find_elements(by = By.CLASS_NAME, value = 'divWCRS310_Content')
                

                for produit in produits:
                    nom_produit = produit.find_element(by = By.CLASS_NAME, value ='pWCRS310_Desc')
                    #print(nom_produit)

                    prix_ent_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUnitairePartieEntiere')
                    #print(prix_ent_produit)
                    prix_dec_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUnitairePartieDecimale')
                    #print(prix_dec_produit)

                    prix_produit = prix_ent_produit.text + prix_dec_produit.text
                    #print(prix_produit)

                    
                    prix_rat_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUniteMesure')
                    #print(prix_rat_produit)
                    

                    dict_produits={
                        'rayon principal' : df_rayons.iloc[i]['rayon principal'],
                        'rayon secondaire': df_rayons.iloc[i]['rayon secondaire'],
                        'lien rayon secondaire' : df_rayons.iloc[i]['lien rayon secondaire'],
                        'nom_produit' : nom_produit.text,
                        'prix_produit' : prix_produit,
                        'prix_rat_produit' : prix_rat_produit.text
                    }
                    #print("--------------------------------")
                    #print(dict_produits)
                    list_produits.append(dict_produits)
            if ((i>98)& (i<102))  : 
                print(i)
                print(lien_rayon)
                driver.get(lien_rayon) 
                time.sleep(2)
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(6)
                produits = driver.find_elements(by = By.CLASS_NAME, value = 'divWCRS310_Content')
                

                for produit in produits:
                    nom_produit = produit.find_element(by = By.CLASS_NAME, value ='pWCRS310_Desc')
                    #print(nom_produit)

                    prix_ent_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUnitairePartieEntiere')
                    #print(prix_ent_produit)
                    prix_dec_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUnitairePartieDecimale')
                    #print(prix_dec_produit)

                    prix_produit = prix_ent_produit.text + prix_dec_produit.text
                    #print(prix_produit)

                    
                    prix_rat_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUniteMesure')
                    #print(prix_rat_produit)
                    

                    dict_produits={
                        'rayon principal' : df_rayons.iloc[i]['rayon principal'],
                        'rayon secondaire': df_rayons.iloc[i]['rayon secondaire'],
                        'lien rayon secondaire' : df_rayons.iloc[i]['lien rayon secondaire'],
                        'nom_produit' : nom_produit.text,
                        'prix_produit' : prix_produit,
                        'prix_rat_produit' : prix_rat_produit.text
                    }
                    #print("--------------------------------")
                    #print(dict_produits)
                    list_produits.append(dict_produits)
            if (i>102)  : 
                print(i)
                print(lien_rayon)
                driver.get(lien_rayon) 
                time.sleep(2)
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(6)
                produits = driver.find_elements(by = By.CLASS_NAME, value = 'divWCRS310_Content')
                

                for produit in produits:
                    nom_produit = produit.find_element(by = By.CLASS_NAME, value ='pWCRS310_Desc')
                    #print(nom_produit)

                    prix_ent_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUnitairePartieEntiere')
                    #print(prix_ent_produit)
                    prix_dec_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUnitairePartieDecimale')
                    #print(prix_dec_produit)

                    prix_produit = prix_ent_produit.text + prix_dec_produit.text
                    #print(prix_produit)

                    
                    prix_rat_produit = produit.find_element(by = By.CLASS_NAME,value = 'pWCRS310_PrixUniteMesure')
                    #print(prix_rat_produit)
                    

                    dict_produits={
                        'rayon principal' : df_rayons.iloc[i]['rayon principal'],
                        'rayon secondaire': df_rayons.iloc[i]['rayon secondaire'],
                        'lien rayon secondaire' : df_rayons.iloc[i]['lien rayon secondaire'],
                        'nom_produit' : nom_produit.text,
                        'prix_produit' : prix_produit,
                        'prix_rat_produit' : prix_rat_produit.text
                    }
                    #print("--------------------------------")
                    #print(dict_produits)
                    list_produits.append(dict_produits)
            else : 
                pass
        df_produits = pd.DataFrame(list_produits)
        df_produits.to_csv('list_all_produits_3.csv')
    except:
        driver.quit()
# Out:
# 0      https://fd11-courses.leclercdrive.fr/magasin-0...
# 1      https://fd11-courses.leclercdrive.fr/magasin-0...
# 2      https://fd11-courses.leclercdrive.fr/magasin-0...
# 3      https://fd11-courses.leclercdrive.fr/magasin-0...
# 4      https://fd11-courses.leclercdrive.fr/magasin-0...
#                              ...
# 106    https://fd11-courses.leclercdrive.fr/magasin-0...
# 107    https://fd11-courses.leclercdrive.fr/magasin-0...
# 108    https://fd11-courses.leclercdrive.fr/magasin-0...
# 109    https://fd11-courses.leclercdrive.fr/magasin-0...
# 110    https://fd11-courses.leclercdrive.fr/magasin-0...
# Name: lien rayon secondaire, Length: 111, dtype: object
# 97
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284649-Accessoires-menagers.aspx
# 99
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284671-Les-chiens.aspx
# 100
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284675-Les-chats.aspx
# 101
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284676-Autres-animaux.aspx
# 103
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-300539-Espace-Culturel.aspx
# 104
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-284689-Jardin-et-Exterieur.aspx
# 105
# https://fd11-courses.leclercdrive.fr/magasin-018201-Montauban---Sapiac/rayon-298251-Bricolage-et-Auto.aspx
